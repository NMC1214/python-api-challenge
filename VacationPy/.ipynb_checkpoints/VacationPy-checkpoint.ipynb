# %% [markdown]
# # VacationPy
# ----
#
# #### Note
# * Keep an eye on your API usage. Use https://developers.google.com/maps/reporting/gmp-reporting as reference for how to monitor your usage and billing.
#
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import gmaps
import os
import json

# Import API key
from api_keys import g_key

# %% [markdown]
# ### Store Part I results into DataFrame
# * Load the csv exported in Part I to a DataFrame

# %%
 # Import the zip city data. Use dtype="object" to ensure all data is read in accurately.
City_Data = pd.read_csv(
    "../WeatherPy/City_Data.csv", dtype="object", encoding="utf-8")

# Visualize
City_Data.head()
# Out:
#   Unnamed: 0           City Cloudiness Country        Date Humidity  Latitude  \
# 0          0       Thompson         75      CA  1619313930       46   55.7435
# 1          1          Khani        100      GE  1619314086       93   41.9563
# 2          2  Batagay-Alyta        100      RU  1619313992       72   67.8006
# 3          3          Binga          9      ZW  1619314086       68  -17.6203
# 4          4        Kavieng         15      PG  1619313991       70   -2.5744
#
#   Longitude Max Temp Wind Speed
# 0  -97.8558     -3.0        3.6
# 1   42.9566      8.0       1.03
# 2  130.4114     -3.2        2.1
# 3   27.3414    19.31       0.57
# 4  150.7967    29.39       4.54

# %% [markdown]
# ### Humidity Heatmap
# * Configure gmaps.
# * Use the Lat and Lng as locations and Humidity as the weight.
# * Add Heatmap layer to map.

# %%
 # Configure gmaps with API key
gmaps.configure(api_key=g_key)

 # Store 'Lat' and 'Lng' into  locations 
locations = City_Data[["Latitude", "Longitude"]].astype(float)

Humidity = City_Data["Humidity"].astype(float)

# %%
# Create a Humidity Heatmap layer
fig = gmaps.figure()

heat_layer = gmaps.heatmap_layer(locations, weights=Humidity, 
                                 dissipating=False, max_intensity=100,
                                 point_radius = 1)

fig.add_layer(heat_layer)

fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %% [markdown]
# ### Create new DataFrame fitting weather criteria
# * Narrow down the cities to fit weather conditions.
# * Drop any rows will null values.

# %%
City_Data = City_Data.dropna()

City_Data['Max Temp'] = City_Data['Max Temp'].astype(float)
City_Data['Wind Speed'] = City_Data['Wind Speed'].astype(float)
City_Data['Cloudiness'] = City_Data['Cloudiness'].astype(float)

# remove cities where cloudiness is not zero, max temp is not between 70 and 80 degrees f, and wind is less than 10 mph
City_Data_Clean2 = City_Data[City_Data.Cloudiness == 0]
City_Data_Clean3 = City_Data_Clean2[City_Data_Clean2['Wind Speed'] < 10]
City_Data_Clean4 = City_Data_Clean3[City_Data_Clean3['Max Temp'] < 26.6667]
City_Data_CleanFinal = City_Data_Clean4[City_Data_Clean4['Max Temp'] > 21.1111]

City_Data_CleanFinal
# Out:
#     Unnamed: 0                City  Cloudiness Country        Date Humidity  \
# 21          21           Caravelas         0.0      BR  1619313794       88
# 29          29             Pirajuí         0.0      BR  1619314087       56
# 52          52           Carnarvon         0.0      AU  1619313938       43
# 53          53          Cuauhtémoc         0.0      MX  1619314090        7
# 67          67         Buritizeiro         0.0      BR  1619314092       45
# 280        280          Blackwater         0.0      AU  1619314121       34
# 296        296              Kharan         0.0      PK  1619314124       39
# 333        333       Florianópolis         0.0      BR  1619313843       83
# 417        417      Port Macquarie         0.0      AU  1619314135       53
# 420        420        Khorramshahr         0.0      IR  1619314144       34
# 437        437               Perth         0.0      AU  1619313849       63
# 462        462              Touros         0.0      BR  1619313961       94
# 487        487  Conceição da Barra         0.0      BR  1619314154       90
# 515        515            Buraidah         0.0      SA  1619314162       28
#
#      Latitude  Longitude  Max Temp  Wind Speed
# 21   -17.7125   -39.2481     23.10        2.06
# 29   -21.9986   -49.4572     23.00        2.57
# 52   -24.8667   113.6333     24.00        3.60
# 53    28.4167  -106.8667     21.67        1.79
# 67   -17.3511   -44.9622     21.56        1.51
# 280  -23.5833   148.8833     25.22        3.36
# 296   28.5833    65.4167     23.08        1.50
# 333  -27.6146   -48.5012     23.89        2.06
# 417  -31.4333   152.9167     22.78        1.79
# 420   30.4397    48.1664     26.00        2.06
# 437  -31.9333   115.8333     22.22        1.03
# 462   -5.1989   -35.4608     24.00        1.03
# 487  -18.5933   -39.7322     22.82        2.23
# 515    26.326     43.975     23.00        1.51

# %% [markdown]
# ### Hotel Map
# * Store into variable named `hotel_df`.
# * Add a "Hotel Name" column to the DataFrame.
# * Set parameters to search for hotels with 5000 meters.
# * Hit the Google Places API for each city's coordinates.
# * Store the first Hotel result into the DataFrame.
# * Plot markers on top of the heatmap.

# %%
Vacation_Weather = City_Data_CleanFinal.copy()

Vacation_Weather["Hotel Name"] = ""

# Vacation_Weather.reset_index()

# Vacation_Weather.drop(['index', 'Unnamed: 0'], axis=1)

Vacation_Weather
# Out:
#     Unnamed: 0                City  Cloudiness Country        Date Humidity  \
# 21          21           Caravelas         0.0      BR  1619313794       88
# 29          29             Pirajuí         0.0      BR  1619314087       56
# 52          52           Carnarvon         0.0      AU  1619313938       43
# 53          53          Cuauhtémoc         0.0      MX  1619314090        7
# 67          67         Buritizeiro         0.0      BR  1619314092       45
# 280        280          Blackwater         0.0      AU  1619314121       34
# 296        296              Kharan         0.0      PK  1619314124       39
# 333        333       Florianópolis         0.0      BR  1619313843       83
# 417        417      Port Macquarie         0.0      AU  1619314135       53
# 420        420        Khorramshahr         0.0      IR  1619314144       34
# 437        437               Perth         0.0      AU  1619313849       63
# 462        462              Touros         0.0      BR  1619313961       94
# 487        487  Conceição da Barra         0.0      BR  1619314154       90
# 515        515            Buraidah         0.0      SA  1619314162       28
#
#      Latitude  Longitude  Max Temp  Wind Speed Hotel Name
# 21   -17.7125   -39.2481     23.10        2.06
# 29   -21.9986   -49.4572     23.00        2.57
# 52   -24.8667   113.6333     24.00        3.60
# 53    28.4167  -106.8667     21.67        1.79
# 67   -17.3511   -44.9622     21.56        1.51
# 280  -23.5833   148.8833     25.22        3.36
# 296   28.5833    65.4167     23.08        1.50
# 333  -27.6146   -48.5012     23.89        2.06
# 417  -31.4333   152.9167     22.78        1.79
# 420   30.4397    48.1664     26.00        2.06
# 437  -31.9333   115.8333     22.22        1.03
# 462   -5.1989   -35.4608     24.00        1.03
# 487  -18.5933   -39.7322     22.82        2.23
# 515    26.326     43.975     23.00        1.51

# %%
vacay_latituds = []

for index, row in Vacation_Weather.iterrows():
    print(row["Latitude"],row["Longitude"])
# Out:
# -17.7125 -39.2481
# -21.9986 -49.4572
# -24.8667 113.6333
# 28.4167 -106.8667
# -17.3511 -44.9622
# -23.5833 148.8833
# 28.5833 65.4167
# -27.6146 -48.5012
# -31.4333 152.9167
# 30.4397 48.1664
# -31.9333 115.8333
# -5.1989 -35.4608
# -18.5933 -39.7322
# 26.326 43.975

# %%
hotels = []

# base url
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

# run a request using our params dictionary
for index, row in Vacation_Weather.iterrows():
 
    # geocoordinates
    target_coordinates = f"{row['Latitude']},{row['Longitude']}"
    target_search = "hotel"
    target_radius = 5000
    target_type = "hotel"

    # set up a parameters dictionary
    params = {
        "location": target_coordinates,
        "keyword": target_search,
        "radius": target_radius,
        "type": target_type,
        "key": g_key
    }

    response = requests.get(base_url, params=params)
    response = response.json()
#     hotels.append(response['name'])
    


#, params=params .json()
# response.status_code
response["results"]
# Vacation_Weather
# Out:
# [{'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3578299, 'lng': 43.9678808},
#    'viewport': {'northeast': {'lat': 26.35929347989272,
#      'lng': 43.96972462989272},
#     'southwest': {'lat': 26.35659382010728, 'lng': 43.96702497010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Mövenpick Hotel Qassim',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1371,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103128291472185251253">فندق موفنبيك</a>'],
#     'photo_reference': 'ATtYBwLrGyxBvJhkL-sg7qY1YfSp58ZVPhL7COlxDwjboKCm2bGP7G6SHbpTmTEzq583uyb_mcjHq9OgyCQyyT5kUK1dNeuR83mDcJpwBoRLLos-uiBqTaJBNKCr7MeaaGpfGZV0k2fSZKs7KhTkJJD2Z4CjL-4NYu9kxRvubebeS5YD_s41',
#     'width': 2048}],
#   'place_id': 'ChIJqYmQxE5YfxURfCXCBPmdDuo',
#   'plus_code': {'compound_code': '9X59+45 Buraydah Saudi Arabia',
#    'global_code': '7HR59X59+45'},
#   'rating': 4.2,
#   'reference': 'ChIJqYmQxE5YfxURfCXCBPmdDuo',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 3076,
#   'vicinity': 'King Khalid Rd, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.363495, 'lng': 43.939046},
#    'viewport': {'northeast': {'lat': 26.36469777989272,
#      'lng': 43.94054967989272},
#     'southwest': {'lat': 26.36199812010728, 'lng': 43.93785002010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Golden Tulip Buraidah',
#   'photos': [{'height': 1424,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114812032119439465131">A Google User</a>'],
#     'photo_reference': 'ATtYBwKjds5GobNDGoZne8s8tUMuVVBzHrm79Id-BzcK_v4t-8GeoqgsesRJR62aZXfX-bjMPTMeMxTJTO3CILPyLO_r5Y79_56XUJrp11u8uO1a4u-wTjtSAyILfKPFO4MF6Aeft0TnX4DLpzNT3PYbgN8IBoIQL6eUFJnSHaBe-02bj_iG',
#     'width': 2048}],
#   'place_id': 'ChIJhY18MIlXfxURyLMr7hzFVXg',
#   'plus_code': {'compound_code': '9W7Q+9J Buraydah Saudi Arabia',
#    'global_code': '7HR59W7Q+9J'},
#   'rating': 4,
#   'reference': 'ChIJhY18MIlXfxURyLMr7hzFVXg',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1931,
#   'vicinity': 'King Abdulaziz Rd, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3675712, 'lng': 43.9423214},
#    'viewport': {'northeast': {'lat': 26.36887547989272,
#      'lng': 43.94360227989272},
#     'southwest': {'lat': 26.36617582010728, 'lng': 43.94090262010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Rollins Hotel',
#   'photos': [{'height': 768,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102801413966860273688">Mohammed Khader</a>'],
#     'photo_reference': 'ATtYBwIqm0bsTSOGLcgKGMQWibpawSFAJkn2yWkG_8aiL8VBDI-ITXb2L76qnRwM2NQLOzdOXpUelwDEaG9Lm6cjtbczxrRygl4y1KKapKkRH_4qnLfPEsa6_D-wGCrEW_uXJJDqGB39sbdBfRWVVzq9wT_PZwJzavGY3GOWayIwOfv_0Za6',
#     'width': 1280}],
#   'place_id': 'ChIJE2iDC4dXfxURHI_u9UH8PzI',
#   'plus_code': {'compound_code': '9W9R+2W Buraydah Saudi Arabia',
#    'global_code': '7HR59W9R+2W'},
#   'rating': 3.9,
#   'reference': 'ChIJE2iDC4dXfxURHI_u9UH8PzI',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 937,
#   'vicinity': 'طريق الملك سعود، الامن، Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3631102, 'lng': 43.9302354},
#    'viewport': {'northeast': {'lat': 26.36441187989272,
#      'lng': 43.93168727989273},
#     'southwest': {'lat': 26.36171222010728, 'lng': 43.92898762010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Best Western Plus Buraidah',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 720,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103386398031905163356">A Google User</a>'],
#     'photo_reference': 'ATtYBwIKIIFAYyW_GblUf9AM4xLneUoNmhEY1XB7OxBfrwv_JPieUcfz_GZ6KSbRoRpYw_XzH68dsyxoQ3moKHTnZ6c2NVVX3brZSSPlY5GLVaAeSBoE5IOg8IgWoBuv5xiMhg-LWwDVus11lgfQfofSMCDXPvCyz5En7moIG0NqGss-w04i',
#     'width': 1280}],
#   'place_id': 'ChIJIVySmZNXfxURkxbuky9pj88',
#   'plus_code': {'compound_code': '9W7J+63 Buraydah Saudi Arabia',
#    'global_code': '7HR59W7J+63'},
#   'rating': 3.9,
#   'reference': 'ChIJIVySmZNXfxURkxbuky9pj88',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1056,
#   'vicinity': "Faisal Bin Misha'L Road, Buraydah"},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3557713, 'lng': 43.9547914},
#    'viewport': {'northeast': {'lat': 26.35711232989272,
#      'lng': 43.95612152989273},
#     'southwest': {'lat': 26.35441267010728, 'lng': 43.95342187010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Sharz Hotel',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112743811376716080363">kamran hafeez</a>'],
#     'photo_reference': 'ATtYBwLRv9elD9Q2smmClkzeoGl7_puqOJwCp7DS1X8adG9XNIwGVQMP2jJrlz7R05CyIfln-5MaAq53xtTmClyiYSumP_oeQrY8bcF-LWEYXYFCaCtTB9vR8gSLNggreeYH21B9L3zKKoe5V6EeWTrVLGgYvEQ2OCQqBAOwQeQqN5XN5zzv',
#     'width': 4032}],
#   'place_id': 'ChIJ0U1yZDtYfxURIhMqSNCis48',
#   'plus_code': {'compound_code': '9X43+8W Buraydah Saudi Arabia',
#    'global_code': '7HR59X43+8W'},
#   'rating': 3.7,
#   'reference': 'ChIJ0U1yZDtYfxURIhMqSNCis48',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1612,
#   'vicinity': 'Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.358865, 'lng': 43.947516},
#    'viewport': {'northeast': {'lat': 26.36035162989272,
#      'lng': 43.94895347989272},
#     'southwest': {'lat': 26.35765197010728, 'lng': 43.94625382010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Ewaa Express Hotel - Buraydah',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3633,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114711788966746141408">A Google User</a>'],
#     'photo_reference': 'ATtYBwIQN4AS04pxY8grbZOWKMhueK191oF09t2YX28taOGNfqjWOk9-aO_yETbq7ZIgW9b4WOMXiG23B4vqRnK1uw24Rq6dSGkBzDpaoOLlk4GLu9rvBcB5RCRAn_83lriGw0oYnpB0-sTYUQx09iLTbLibMiJezU6Y4qp-x8lvzj2b8749',
#     'width': 5449}],
#   'place_id': 'ChIJMQDwuSZYfxUResc-8pNmw_I',
#   'plus_code': {'compound_code': '9W5X+G2 Buraydah Saudi Arabia',
#    'global_code': '7HR59W5X+G2'},
#   'rating': 3.9,
#   'reference': 'ChIJMQDwuSZYfxUResc-8pNmw_I',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 445,
#   'vicinity': 'Dist، King Abdulaziz Rd, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3555264, 'lng': 43.9641974},
#    'viewport': {'northeast': {'lat': 26.35681777989272,
#      'lng': 43.96561977989273},
#     'southwest': {'lat': 26.35411812010728, 'lng': 43.96292012010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'فندق براند القصيم',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1467,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108275878101318927010">A Google User</a>'],
#     'photo_reference': 'ATtYBwLQS_Dp8cyvPHHJI0vTEL8N6qfA1M4fC9eLNsmlzh0gtnH0wigw-rjZATjudIndRZ8N86b5vCfro9HFheb-IMrkBdK70dMfr30Z1ISQuE1Vz5QUhY8c9Vpo-cozDC103icyUrOgiKfsnatFMZ4SIW2zwvDesuodhrEtf7CRmqCB9xS7',
#     'width': 2200}],
#   'place_id': 'ChIJhQgMZwJZfxURZQ6rFx4RuSo',
#   'plus_code': {'compound_code': '9X47+6M Buraydah Saudi Arabia',
#    'global_code': '7HR59X47+6M'},
#   'rating': 4.4,
#   'reference': 'ChIJhQgMZwJZfxURZQ6rFx4RuSo',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 177,
#   'vicinity': 'King Fahd Rd, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3586442, 'lng': 43.951359},
#    'viewport': {'northeast': {'lat': 26.36006012989272,
#      'lng': 43.95267112989272},
#     'southwest': {'lat': 26.35736047010728, 'lng': 43.94997147010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'فندق تاورز HOTELTOWERS',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 960,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101658992649237732186">A Google User</a>'],
#     'photo_reference': 'ATtYBwIMlBrXoU88LJuzne5-_AIf12990baY51lMqMCvqsGC7JjDcda24mwdmJEFICrhm2FuKqkAlttvTisWuVGlOXEDEPRw0RHCOijChlKLhUWyHC-kH4uUHcvkoKvGuycapOk7au8UHzozvbaptrLVUvnXDTCrITo9qa0bMjKhLoqs4j4',
#     'width': 1280}],
#   'place_id': 'ChIJTQ6aL9VZfxURgeHPLXEIT-k',
#   'plus_code': {'compound_code': '9X52+FG Buraydah Saudi Arabia',
#    'global_code': '7HR59X52+FG'},
#   'rating': 4.6,
#   'reference': 'ChIJTQ6aL9VZfxURgeHPLXEIT-k',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 100,
#   'vicinity': 'Prince Sultan Ibn Abdulaziz Rd, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3641466, 'lng': 43.94939919999999},
#    'viewport': {'northeast': {'lat': 26.36543672989272,
#      'lng': 43.95061922989272},
#     'southwest': {'lat': 26.36273707010728, 'lng': 43.94791957010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'قصر هليون',
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111886177732876073226">omar alsharif</a>'],
#     'photo_reference': 'ATtYBwIIlVfqwuneUBlXOu726vPD_G9k1AwFYWMtz-x-VYcJdaGn2AYAPbHqneNN8zBBY00wzhOPTJXNnneasUh48ARhWqm7zjuWFQxr75_jexpv31P75gXATksY06xlyRhAnbvmX4H0TSpu9GPadjTuI4flUiqCnNw55ojNk5MOPUVTiGGL',
#     'width': 3024}],
#   'place_id': 'ChIJozgWOy9YfxURORgR249hNNc',
#   'plus_code': {'compound_code': '9W7X+MQ Buraydah Saudi Arabia',
#    'global_code': '7HR59W7X+MQ'},
#   'rating': 3.8,
#   'reference': 'ChIJozgWOy9YfxURORgR249hNNc',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 222,
#   'vicinity': 'Abu Bakr As Siddiq Road, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3316858, 'lng': 43.9701033},
#    'viewport': {'northeast': {'lat': 26.33298862989272,
#      'lng': 43.97148722989272},
#     'southwest': {'lat': 26.33028897010728, 'lng': 43.96878757010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'YARA SUITES',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2570,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118337270586565627759">A Google User</a>'],
#     'photo_reference': 'ATtYBwJkCVoy7Z0J9J4JhwmtYo2FcIk4PN-CFs5VzkegVfbuYPJAiajeDJs391qNVL6LSkJ5iaJuuDIa9mLgBBC_mhNEeYQj8aLqSgyCX1wumYrVby3HzGkfh51Yfks8kwGiOg-Oly6cudAbvcCmjGrIrG5lneBBMcVytp9oFjpYlfRGGm6c',
#     'width': 3855}],
#   'place_id': 'ChIJNSLF3nBYfxURXd5X6_JdHIA',
#   'plus_code': {'compound_code': '8XJC+M2 Buraydah Saudi Arabia',
#    'global_code': '7HR58XJC+M2'},
#   'rating': 3.5,
#   'reference': 'ChIJNSLF3nBYfxURXd5X6_JdHIA',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 206,
#   'vicinity': '3762 Al Wihdah, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3614541, 'lng': 43.9502102},
#    'viewport': {'northeast': {'lat': 26.36285072989272,
#      'lng': 43.95166402989272},
#     'southwest': {'lat': 26.36015107010728, 'lng': 43.94896437010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Zaidan Hotel Suites',
#   'photos': [{'height': 2322,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113161997506463964977">A Google User</a>'],
#     'photo_reference': 'ATtYBwLACCDTCK4XJSh3BUbXfjUUaY2Of9uF3taXHlYj2AGmFRxphFNOwUcPle8ypkYkv1ffoaKr2RH6vJyKaLjmlzBfqQgGHncX6uK9Ob9cIxIiBcnLBUSyJNYRuQ3jLbnh5F7F4k4if4KQY12cptsMAITXH8ReGtXtswnJtDMfTE1CE22i',
#     'width': 4128}],
#   'place_id': 'ChIJKUyEjyVYfxURohR8NYC5NSQ',
#   'plus_code': {'compound_code': '9X62+H3 Buraydah Saudi Arabia',
#    'global_code': '7HR59X62+H3'},
#   'rating': 3.5,
#   'reference': 'ChIJKUyEjyVYfxURohR8NYC5NSQ',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 248,
#   'vicinity': 'Abu Bakr As Siddiq Road, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.366727, 'lng': 43.964976},
#    'viewport': {'northeast': {'lat': 26.36814077989272,
#      'lng': 43.96648192989272},
#     'southwest': {'lat': 26.36544112010728, 'lng': 43.96378227010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Zievle Hotel Apartments',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114021866413370526722">علي ال عبدالله</a>'],
#     'photo_reference': 'ATtYBwJkjAR8q-IWSACbcLWmCjtMcxBqqirZ12qf371WH2hRtOqyUBhz-3tThAqKNsROYNeiZGWpg9jhznKQzoMydOeRh-8fW6wXWUfZEVTXeVCA2WmNLrJ8vH6jAJZL1QisCrSQSJCw98M9MTS4TX9myZ6h3RC6pk7sqMDUDnsGrGg5kxCl',
#     'width': 4032}],
#   'place_id': 'ChIJWUpf3rRZfxUR-NMiL3hD30I',
#   'plus_code': {'compound_code': '9X87+MX Buraydah Saudi Arabia',
#    'global_code': '7HR59X87+MX'},
#   'rating': 3.6,
#   'reference': 'ChIJWUpf3rRZfxUR-NMiL3hD30I',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 407,
#   'vicinity': 'طريق الملك خالد، الصفراء، Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3454789, 'lng': 43.9498455},
#    'viewport': {'northeast': {'lat': 26.34687112989272,
#      'lng': 43.95117572989272},
#     'southwest': {'lat': 26.34417147010728, 'lng': 43.94847607010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Vision Apartment',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3968,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106688040420197613204">وليد امام</a>'],
#     'photo_reference': 'ATtYBwKwnj8VFGuX1PX_W4oGv7fUqsACY6WXV0czU7WsupgRsU3hv_6cZuUYJERVRLf3YhrxMSX_BPM07HBrAZiu9S1oraJTdznLflt4HJf3Ug9xIyOy9I-nBSsl2wL_aWYXef6LQNzINOyHQCbEI1Sgyku0HSAPFS9KMNe4blUBeO94egKi',
#     'width': 2976}],
#   'place_id': 'ChIJ2ZcIoBtYfxURCoPwdxHX3AM',
#   'plus_code': {'compound_code': '8WWX+5W Buraydah Saudi Arabia',
#    'global_code': '7HR58WWX+5W'},
#   'rating': 3.8,
#   'reference': 'ChIJ2ZcIoBtYfxURCoPwdxHX3AM',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 765,
#   'vicinity': 'King Fahd Branch Rd, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.367362, 'lng': 43.964854},
#    'viewport': {'northeast': {'lat': 26.36874152989272,
#      'lng': 43.96627302989271},
#     'southwest': {'lat': 26.36604187010727, 'lng': 43.96357337010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'منازل الحمراء 2',
#   'photos': [{'height': 460,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114160119932813312149">سمير العنسي</a>'],
#     'photo_reference': 'ATtYBwIqSmCE63cgEl_upQIbdYhWGSjjF61OBnGqgbKU-Pgkb1am_XLwTThrLmYteKRSOrWM8BwgRqDPPJj1EV9_5-4qejNdfyNu2kSGyiaoYuLeHM3oNF6hK6ZZbdD-JfO-tZItOQvgHVnCGla8jhYt5nFcZvmdNDcJszpoXkVyK7Yttfyk',
#     'width': 840}],
#   'place_id': 'ChIJFyHiHLVZfxURKwtGwYp6Kqw',
#   'plus_code': {'compound_code': '9X87+WW Buraydah Saudi Arabia',
#    'global_code': '7HR59X87+WW'},
#   'rating': 3.9,
#   'reference': 'ChIJFyHiHLVZfxURKwtGwYp6Kqw',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 177,
#   'vicinity': 'King Khalid Raod، Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3182388, 'lng': 43.9876247},
#    'viewport': {'northeast': {'lat': 26.31965092989272,
#      'lng': 43.98893472989272},
#     'southwest': {'lat': 26.31695127010727, 'lng': 43.98623507010727}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'Pearl Najd Hotel Suites',
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105018338683806109065">عالم ثاني</a>'],
#     'photo_reference': 'ATtYBwKk6qbgwzqRDte34iIA6FuQ4TbgrgAuxMk42fnz_JxQaCR-MKQPxp6vEH0HzmqdxpVyOW4iGB5CYI1wuxxvS7gsT35JUUIIogCFsw6XOgQODJkGaFSu0Qp2cerscmcH7BbyLkgS-dGysuqUy3XKVzx1za2lHK6P6sGAcB3hXwvirnfC',
#     'width': 4032}],
#   'place_id': 'ChIJgxmAuXjigRURs5PwtMv9R0A',
#   'plus_code': {'compound_code': '8X9Q+72 Buraydah Saudi Arabia',
#    'global_code': '7HR58X9Q+72'},
#   'rating': 3.5,
#   'reference': 'ChIJgxmAuXjigRURs5PwtMv9R0A',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 76,
#   'vicinity': 'King Khalid Rd, Buraydah'},
#  {'business_status': 'OPERATIONAL',
#   'geometry': {'location': {'lat': 26.3184024, 'lng': 43.9882484},
#    'viewport': {'northeast': {'lat': 26.31987682989272,
#      'lng': 43.98953687989272},
#     'southwest': {'lat': 26.31717717010727, 'lng': 43.98683722010728}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png',
#   'name': 'الماسة الخليج للشقق المفروشة',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 960,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111979925897191287737">Mishaal Almutairi</a>'],
#     'photo_reference': 'ATtYBwJeERCBCFyWI-I6IvOXCruYwfpxye9FGK77ktJUbCakuG_9zD9T6DIl_AmFBcHvSdpmcRzlrrCOE5gBuC7qflSgaG-h9eX1CFS3Z59U59oms4CAn-Fb4NqK0L7G_nZlw3FAcjcMzQIxVVtFlYa5AFEix5brrpzFLAtoxIsqb7EQmEvI',
#     'width': 1280}],
#   'place_id': 'ChIJR4Xdc1rjgRURoihCedo86AE',
#   'plus_code': {'compound_code': '8X9Q+97 Buraydah Saudi Arabia',
#    'global_code': '7HR58X9Q+97'},
#   'rating': 4,
#   'reference': 'ChIJR4Xdc1rjgRURoihCedo86AE',
#   'scope': 'GOOGLE',
#   'types': ['lodging', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 97,
#   'vicinity': 'King Khalid Rd, Buraydah'}]

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in hotel_df.iterrows()]
locations = hotel_df[["Lat", "Lng"]]

# %%
# Add marker layer ontop of heat map


# Display figure
